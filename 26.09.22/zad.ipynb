# %% [markdown]
# Вычисление при помощи scipy интеграла вида:![Снимок экрана 2022-10-01 в 21.30.23.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2022-10-01 в 22.09.54.png](data:image/png;base64,...)

# %%
from scipy import integrate

# %%
def f(x):
  return x**3 / (x**8 -  2)

# %%
integrate.quad(f, 0, 1.0)
# Out:
# (-0.15580631003505763, 1.3706114467140702e-12)

# %% [markdown]
# как видно результаты сошлись. Ответ ≈-0.1558
